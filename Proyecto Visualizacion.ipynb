# %%
from selenium import webdriver # driver de selenium

import time   # para manejar tiempo

from selenium.webdriver.chrome.options import Options

from selenium.webdriver.common.by import By   # para buscar segun tag, id, class, etc...

from selenium.webdriver.support.ui import WebDriverWait   # es para esperar

from selenium.webdriver.support import expected_conditions as EC  # condiciones esperadas...

from selenium.webdriver import ActionChains as AC   # acciones encadenadas, rollo doble click

from selenium.webdriver.common.keys import Keys  # manejar teclas


import warnings
warnings.filterwarnings('ignore')

# %%
from selenium import webdriver

import time

import pandas as pd


import pylab as plt

import seaborn as sns

from webdriver_manager.chrome import ChromeDriverManager

import requests as req

from bs4 import BeautifulSoup as bs

PATH=ChromeDriverManager().install()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Could not get version for google-chrome. Is google-chrome installed?
# [WDM] - Get LATEST chromedriver version for None google-chrome
# [WDM] - About to download new driver from https://chromedriver.storage.googleapis.com/103.0.5060.53/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\javip\.wdm\drivers\chromedriver\win32\103.0.5060.53]

# %%
import pandas as pd
import numpy as np
import os as os
from joblib import Parallel, delayed
from webdriver_manager.chrome import ChromeDriverManager

PATH=ChromeDriverManager().install()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Could not get version for google-chrome. Is google-chrome installed?
# [WDM] - Get LATEST chromedriver version for None google-chrome
# [WDM] - Driver [C:\Users\javip\.wdm\drivers\chromedriver\win32\103.0.5060.53\chromedriver.exe] found in cache

# %%
pwd
# Out:
# 'C:\\Users\\javip\\Lab1\\Proyecto-Dashboard'

# %%
opciones=Options()

# quita la bandera de ser robot
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=False   # si True, no aparece la ventana (headless=no visible)

opciones.add_argument('--start-maximized')         # comienza maximizado

opciones.add_experimental_option('detach', True)

#opciones.add_argument('user-data-dir=selenium')    # mantiene las coockies

# %%
driver = "C:/Users/javip/Downloads/chromedriver_win32/chromedriver.exe"
driver = webdriver.Chrome(PATH,options = opciones)

# %% [markdown]
# # Datos Mcdonals

# %%
Productos= {'//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[1]/a': 'BigMac','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[2]/a':'McRoyal_Deluxe','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[3]/a':'McSpicy','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[4]/a':'Cuarto_de_Libra','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[5]/a':'McPollo','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[6]/a':'CBO','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[7]/a':'Signature_Queso_de_Cabra','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[8]/a':'Signature_Queso_de_Cabra_Doble','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[9]/a':'American_Style_Chicken_Buffalo','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[10]/a':'American_Style_Chicken_Honey_Mustard','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[11]/a':'Grand_McExtreme_Intense_Chedar','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[12]/a':'Grand_McExtreme_Intense_Chedar_Doble','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[13]/a':'Grand_McExtreme_Bacon','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[14]/a':'Grand_McExtreme_Bacon_Doble','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[15]/a':'Hamburguesa','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[16]/a':'Cheeseburguer','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[17]/a':'Doble_Cheeseburguer','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[18]/a':'Triple_Cheeseburguer','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[19]/a':'Chicken&Cheese','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[21]/a':'McWrap','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[21]/a':'Chicken_Burguer_BBQ','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[22]/a':'Filete_de_Pescado','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[23]/a':'McFish','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[24]/a':'Chicken_Mayo','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[25]/a':'Doble_Chicken_Mayo','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[26]/a':'Triple_Chicken_Mayo'}
#'//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[9]/a':'4 Alitas de Pollo',,'//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[13]/a':'Gazpacho'
Desayunos={'//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[1]/a':'Croissant de Mantequilla','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[2]/a':'Deseo de Tortilla de Patata','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[3]/a':'Tostada de iberico','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[4]/a':'Tostada con Aceite y Tomate','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[5]/a':'Muffin de Chocolate','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[6]/a':'Redondo Glaseado','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[7]/a':'Redondo Bombon'}
Ensaladas={'//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[1]/a':'Ensalada Cesar','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[2]/a':'Ensalada de la huerta','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[3]/a':'Ensalada Queso de Cabra'}
Entrantes={'//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[1]/a':'McShaker Fries','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[2]/a':'McShaker Fries Deluxe','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[3]/a':'Top Fries Bacon Cheese','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[4]/a':'Top Fries Bacon Cheese Deluxe','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[5]/a':'Patatas Fritas','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[6]/a':'Patatas Deluxe','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[7]/a':'4 McNuggets','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[8]/a':'9 Chicken McBites','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[10]/a':'Maxi Cubo 25 McNuggets','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[11]/a':'Maxi Cubo 10 Alitas y 10 McNuggets','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[12]/a':'Happy Cherritos'}
Postres= {'//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[1]/a':'McFlurry Nocilla y Cookies','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[2]/a':'Mcflurry M&M con cacahuetes','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[3]/a':'McFlurry KitKat','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[4]/a':'McFlurry Oreo','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[5]/a':'McFlurry Oreo Chocolate Blanco','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[6]/a':'Apple Pie','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[7]/a':'Cono de Helado','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[8]/a':'Sundae Chocolate','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[9]/a':'Sundae Caramelo','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[10]/a':'Sundae Fresa','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[11]/a':'Sundae Chocolate Blanco','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[13]/a':'Mini McFlurry Nocilla y Cookies','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[13]/a':'Mini McFlurry M&Ms con cacahuete','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[14]/a':'Mini McFlurry KitKat','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[15]/a':'Mini McFlurry Oreo','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[16]/a':'Danonino Street Fresa','//*[@id="__layout"]/div/div/main/div/div/div/div/div/section/div/nav/ul/li[17]/a':'Actimel Fresa Platano'}

# %%
def sacarinfomcdonals3(xpath,col):
    #url='https://mcdonalds.es/productos/sandwiches-principales'  #Principales
    #url = 'https://mcdonalds.es/productos/complementos'  # Complementos
    #url = 'https://mcdonalds.es/productos/postres-y-helados'  #Postres
    url = 'https://mcdonalds.es/productos/ensaladas'   #Ensaladas
    #url = 'https://mcdonalds.es/productos/mc-breakfast'   #Desayunos
    
    driver=webdriver.Chrome(PATH)
    driver.get(url)
    
    time.sleep(2)
    
    cookie=driver.find_element_by_xpath('//*[@id="onetrust-accept-btn-handler"]')
    cookie.click()  # Darle al boton de aceptar cookies
    
    time.sleep(3)
    


    producto=driver.find_element_by_xpath(f"{xpath}")
    producto.click()  #Buscar por xpath a la hamburguesa que darle
    
    time.sleep(2)
    
    nowurl= driver.current_url  #Cogeme el URL en el que estas actualmente
    
    html=req.get(nowurl).content
    
    soup=bs(html, 'html.parser')
    
    tabla=soup.find_all('table') #Busca dentro del tag tabla
    
    elementos = tabla[0].find_all('td') # Encuentrame cada tag td
    Bigmac=[f.text.strip().split('<td>') for f in elementos] #borra td del texto
    ahorasi= []
    for e in Bigmac:  # Por cada elemento en lista y por cada elemento dentro de estos 
        for u in e:
            if u == '':  # Si esta vacio borra
                del(u)
            elif u == 'Peso':   #Chapuzas de MCdonals
                del(u)
            elif u == '124Peso':
                del(u)
            elif u =='239g':
                del(u)
            elif u =='333g':
                del(u)
            elif u =='263g':
                del(u)
            elif u =='105g':
                del(u)
            elif u =='237,2g':
                del(u)
            elif u =='186,6g':
                del(u)
            elif u =='136g':
                del(u)
            elif u =='g':
                del(u)
            elif u =='137g':
                del(u)
            elif u =='127g':
                del(u)
            elif u =='218,4g':
                del(u)
            elif u =='170,4g':
                del(u)
            elif u =='264g':
                del(u)
            elif u =='248,2g':
                del(u)
            elif u =='239g':
                del(u)
            elif u =='279':
                del(u)
            elif u =='256g':
                del(u)
            elif u =='348g':
                del(u)
            elif u =='236,4g':
                del(u)
            elif u =='226g':
                del(u)
            elif u == '234g':
                del(u)
            elif u == '128g':
                del(u)
            elif u == '120g':
                del(u)
            elif u == '130g':
                del(u)
            elif u == '116.5g':
                del(u)
            elif u == '112.5g':
                del(u)
            elif u == '120g':
                del(u)
            elif u == '149g':
                del(u)
            elif u == '80g':
                del(u)
            elif u == '128g':
                del(u)
            elif u == '110g':
                del(u)
            elif u == '72g':
                del(u)
            elif u == '61g':
                del(u)
            elif u == '449g':
                del(u)
            elif u == '50g':
                del(u)
            elif u == '133g':
                del(u)
            elif u == '221g':
                del(u)
            elif u == '62g':
                del(u)
            elif u == '197g':
                del(u)
            elif u == '210,8g':
                del(u)
            elif u == '210g':
                del(u)
            elif u == '200g':
                del(u)
            elif u == '190g':
                del(u)
            elif u == '85g':
                del(u)
            elif u == '92g':
                del(u)
            elif u == '166g':
                del(u)
            elif u == '159g':
                del(u)
            elif u == '95g':
                del(u)
            elif u == '99ml':
                del(u)
            
            else:
                ahorasi.append(u) # Si no metemelo aqui en esta lista
                
                
     #Creame este diccionario  ( Un poco chapuzalia)          
                
    ciengramos = [ahorasi[5],ahorasi[9],ahorasi[13],ahorasi[17],ahorasi[20],ahorasi[24],ahorasi[28],ahorasi[32]]
    racion = [ahorasi[6],ahorasi[10],ahorasi[14],ahorasi[18],ahorasi[21],ahorasi[25],ahorasi[29],ahorasi[33]]
    
    #Creame un dataframe con este diccionario y añademe la Columna 'Producto' con el valor que yo te diga
    #Creame una columna con el nombre del restaurante para poder unir en SQL
    
   
    ciengramos.insert(0, f"{col}")
    ciengramos.insert(9,'Mcdonals')
    racion.insert(0, f"{col}")
    racion.insert(9,'Mcdonals')
    
   
    
    
   
    return ciengramos,racion

# %% [markdown]
# # Sacar datos de Postres

# %%
intermedio= []
racion= []
for xpath,nombres in Postres.items():
        hambu=sacarinfomcdonals3(xpath,nombres)
        
        intermedio.append(hambu[0])
        racion.append(hambu[1])
        
        
        
Postres100 = pd.DataFrame(intermedio, columns= ['Producto','Calorias(100g)','Proteinas(100g)','Hidratos_Carbono(100g)','Fibra(100g)','Azucares(100g)','Grasas(100g)','Grasas_Saturadas(100g)','Sal(100g)','Restaurante'])
PostresRacion = pd.DataFrame(racion, columns= ['Producto','Calorias','Proteinas','Hidratos_Carbono','Fibra','Azucares','Grasas','Grasas_Saturadas','Sal','Restaurante'])

# %% [markdown]
# # Sacar datos de Desayunos

# %%
intermedio= []
racion= []
for xpath,nombres in Desayunos.items():
        hambu=sacarinfomcdonals3(xpath,nombres)
        
        intermedio.append(hambu[0])
        racion.append(hambu[1])
        
        
        
Desayunos100 = pd.DataFrame(intermedio, columns= ['Producto','Calorias(100g)','Proteinas(100g)','Hidratos_Carbono(100g)','Fibra(100g)','Azucares(100g)','Grasas(100g)','Grasas_Saturadas(100g)','Sal(100g)','Restaurante'])
DesayunosRacion = pd.DataFrame(racion, columns= ['Producto','Calorias','Proteinas','Hidratos_Carbono','Fibra','Azucares','Grasas','Grasas_Saturadas','Sal','Restaurante'])

# %% [markdown]
# # Sacar datos de Principales

# %%
intermedio= []
racion= []
for xpath,nombres in Productos.items():
        hambu=sacarinfomcdonals3(xpath,nombres)
        
        intermedio.append(hambu[0])
        racion.append(hambu[1])
        
        
        
Principales100 = pd.DataFrame(intermedio, columns= ['Producto','Calorias(100g)','Proteinas(100g)','Hidratos_Carbono(100g)','Fibra(100g)','Azucares(100g)','Grasas(100g)','Grasas_Saturadas(100g)','Sal(100g)','Restaurante'])
PrincipalesRacion = pd.DataFrame(racion, columns= ['Producto','Calorias','Proteinas','Hidratos_Carbono','Fibra','Azucares','Grasas','Grasas_Saturadas','Sal','Restaurante'])

# %% [markdown]
# # Sacar datos de Ensaladas

# %%
intermedio= []
racion= []
for xpath,nombres in Ensaladas.items():
        hambu=sacarinfomcdonals3(xpath,nombres)
        
        intermedio.append(hambu[0])
        racion.append(hambu[1])
        
        
        
Ensaladas100 = pd.DataFrame(intermedio, columns= ['Producto','Calorias(100g)','Proteinas(100g)','Hidratos_Carbono(100g)','Fibra(100g)','Azucares(100g)','Grasas(100g)','Grasas_Saturadas(100g)','Sal(100g)','Restaurante'])
EnsaladasRacion = pd.DataFrame(racion, columns= ['Producto','Calorias','Proteinas','Hidratos_Carbono','Fibra','Azucares','Grasas','Grasas_Saturadas','Sal','Restaurante'])

# %% [markdown]
# # Sacar datos de Entrantes

# %%
intermedio= []
racion= []
for xpath,nombres in Entrantes.items():
        hambu=sacarinfomcdonals3(xpath,nombres)
        
        intermedio.append(hambu[0])
        racion.append(hambu[1])
        
        
        
Entrantes100 = pd.DataFrame(intermedio, columns= ['Producto','Calorias(100g)','Proteinas(100g)','Hidratos_Carbono(100g)','Fibra(100g)','Azucares(100g)','Grasas(100g)','Grasas_Saturadas(100g)','Sal(100g)','Restaurante'])
EntrantesRacion = pd.DataFrame(racion, columns= ['Producto','Calorias','Proteinas','Hidratos_Carbono','Fibra','Azucares','Grasas','Grasas_Saturadas','Sal','Restaurante'])

# %%
Entrantes100.loc[0,'Calorias(100g)'] = '291kcal'
Entrantes100.loc[0,'Proteinas(100g)'] = '3,6g'
Entrantes100.loc[0,'Hidratos_Carbono(100g)'] = '37g'
Entrantes100.loc[0,'Fibra(100g)'] = '3,5g'
Entrantes100.loc[0,'Azucares(100g)'] = '0,6g'
Entrantes100.loc[0,'Grasas(100g)'] = '14g'
Entrantes100.loc[0,'Grasas_Saturadas(100g)'] = '1,4g'
Entrantes100.loc[0,'Sal(100g)'] = '0,74g'
Entrantes100.loc[1,'Calorias(100g)'] = '204kcal'
Entrantes100.loc[1,'Proteinas(100g)'] = '3g'
Entrantes100.loc[1,'Hidratos_Carbono(100g)'] = '26g'
Entrantes100.loc[1,'Fibra(100g)'] = '2,9g'
Entrantes100.loc[1,'Azucares(100g)'] = '0,6g'
Entrantes100.loc[1,'Grasas(100g)'] = '8,9g'
Entrantes100.loc[1,'Grasas_Saturadas(100g)'] = '1g'
Entrantes100.loc[1,'Sal(100g)'] = '1g'
Entrantes100.loc[3,'Calorias(100g)'] = '212kcal'
Entrantes100.loc[3,'Proteinas(100g)'] = '5,5g'
Entrantes100.loc[3,'Hidratos_Carbono(100g)'] = '21g'
Entrantes100.loc[3,'Fibra(100g)'] = '2,4g'
Entrantes100.loc[3,'Azucares(100g)'] = '0,3g'
Entrantes100.loc[3,'Grasas(100g)'] = '11g'
Entrantes100.loc[3,'Grasas_Saturadas(100g)'] = '2,7g'
Entrantes100.loc[3,'Sal(100g)'] = '1,2g'
Entrantes100
# Out:
#                               Producto Calorias(100g) Proteinas(100g)  \
# 0                       McShaker Fries        291kcal            3,6g
# 1                McShaker Fries Deluxe        204kcal              3g
# 2               Top Fries Bacon Cheese        284kcal            7,9g
# 3        Top Fries Bacon Cheese Deluxe        212kcal            5,5g
# 4                       Patatas Fritas        289kcal            3,4g
# 5                       Patatas Deluxe        200kcal            2,8g
# 6                          4 McNuggets        243kcal             15g
# 7                    9 Chicken McBites        230kcal             16g
# 8               Maxi Cubo 25 McNuggets        249kcal             16g
# 9   Maxi Cubo 10 Alitas y 10 McNuggets        242kcal             20g
# 10                     Happy Cherritos         29kcal            1,2g
#
#    Hidratos_Carbono(100g) Fibra(100g) Azucares(100g) Grasas(100g)  \
# ...

# %%
Entrantes100.insert(10,'Tipo','Entrante', allow_duplicates=False)
EntrantesRacion.insert(10,'Tipo','Entrante', allow_duplicates=False)

# %%
EntrantesRacion.loc[0,'Calorias'] = '338kcal'
EntrantesRacion.loc[0,'Proteinas'] = '4,2g'
EntrantesRacion.loc[0,'Hidratos_Carbono'] = '43g'
EntrantesRacion.loc[0,'Fibra'] = '4.1g'
EntrantesRacion.loc[0,'Azucares'] = '0,7g'
EntrantesRacion.loc[0,'Grasas'] = '16g'
EntrantesRacion.loc[0,'Grasas_Saturadas'] = '1,6g'
EntrantesRacion.loc[0,'Sal'] = '0,86g'

EntrantesRacion.loc[1,'Calorias'] = '229kcal'
EntrantesRacion.loc[1,'Proteinas'] = '3,4g'
EntrantesRacion.loc[1,'Hidratos_Carbono'] ='30g'
EntrantesRacion.loc[1,'Fibra'] = '3,3g'
EntrantesRacion.loc[1,'Azucares'] = '0,7gg'
EntrantesRacion.loc[1,'Grasas'] = '10g'
EntrantesRacion.loc[1,'Grasas_Saturadas'] = '1,1g'
EntrantesRacion.loc[1,'Sal'] = '1,2g'

EntrantesRacion.loc[3,'Calorias'] = '413kcal'
EntrantesRacion.loc[3,'Proteinas'] = '11g'
EntrantesRacion.loc[3,'Hidratos_Carbono'] = '42g'
EntrantesRacion.loc[3,'Fibra'] = '4,7g'
EntrantesRacion.loc[3,'Azucares'] = '0,6g'
EntrantesRacion.loc[3,'Grasas'] = '21g'
EntrantesRacion.loc[3,'Grasas_Saturadas'] = '5,2g'
EntrantesRacion.loc[3,'Sal'] = '2,4g'


EntrantesRacion
# Out:
#                               Producto  Calorias Proteinas Hidratos_Carbono  \
# 0                       McShaker Fries   338kcal      4,2g              43g
# 1                McShaker Fries Deluxe   229kcal      3,4g              30g
# 2               Top Fries Bacon Cheese   423kcal       12g              42g
# 3        Top Fries Bacon Cheese Deluxe   413kcal       11g              42g
# 4                       Patatas Fritas   231kcal      2,8g              29g
# 5                       Patatas Deluxe   220kcal      3,1g              28g
# 6                          4 McNuggets   176kcal       11g              13g
# 7                    9 Chicken McBites   140kcal      9,8g              10g
# 8               Maxi Cubo 25 McNuggets  1116kcal       70g              77g
# 9   Maxi Cubo 10 Alitas y 10 McNuggets  1593kcal      129g              65g
# 10                     Happy Cherritos    15kcal      0,6g             2,2g
#
# ...

# %%
Principales100.insert(10,'Tipo','Principal', allow_duplicates=False)
Principales100
# Out:
#                                 Producto Calorias(100g) Proteinas(100g)  \
# 0                                 BigMac        232kcal             12g
# 1                         McRoyal_Deluxe        222kcal             12g
# 2                                McSpicy        261kcal             12g
# 3                        Cuarto_de_Libra        255kcal             15g
# 4                                McPollo        229kcal             10g
# 5                                    CBO        255kcal             11g
# 6               Signature_Queso_de_Cabra        278kcal             12g
# 7         Signature_Queso_de_Cabra_Doble        277kcal             15g
# 8         American_Style_Chicken_Buffalo        282kcal             11g
# 9   American_Style_Chicken_Honey_Mustard        291kcal             11g
# 10        Grand_McExtreme_Intense_Chedar        297kcal             17g
# 11  Grand_McExtreme_Intense_Chedar_Doble        290kcal             18g
# ...

# %%
PrincipalesRacion.insert(10,'Tipo','Principal', allow_duplicates=False)
PrincipalesRacion
# Out:
#                                 Producto Calorias Proteinas Hidratos_Carbono  \
# 0                                 BigMac  503kcal       26g              42g
# 1                         McRoyal_Deluxe  530kcal       29g              33g
# 2                                McSpicy  591kcal       27g              51g
# 3                        Cuarto_de_Libra  521kcal       32g              37g
# 4                                McPollo  427kcal       19g              43g
# 5                                    CBO  603kcal       25g              53g
# 6               Signature_Queso_de_Cabra  732kcal       32g              55g
# 7         Signature_Queso_de_Cabra_Doble  962kcal       53g              55g
# 8         American_Style_Chicken_Buffalo  720kcal       28g              79g
# 9   American_Style_Chicken_Honey_Mustard  811kcal       31g              81g
# 10        Grand_McExtreme_Intense_Chedar  736kcal       41g              50g
# ...

# %%
Desayunos100.insert(10,'Tipo','Complementos', allow_duplicates=False)
Desayunos100
# Out:
#                       Producto Calorias(100g) Proteinas(100g)  \
# 0     Croissant de Mantequilla        371kcal              7g
# 1  Deseo de Tortilla de Patata        237kcal            5,4g
# 2           Tostada de iberico        270kcal            7,8g
# 3  Tostada con Aceite y Tomate        283kcal            5,3g
# 4          Muffin de Chocolate        441kcal            5,8g
# 5             Redondo Glaseado        412kcal            5,4g
# 6               Redondo Bombon        448kcal            6,9g
#
#   Hidratos_Carbono(100g) Fibra(100g) Azucares(100g) Grasas(100g)  \
# 0                    43g        0,5g           6,6g          19g
# 1                    26g        1,8g           1,9g          12g
# 2                    26g          2g             3g          14g
# 3                    32g        3,3g           2,1g          14g
# 4                    45g        2,4g            28g          26g
# 5                    42g        3,3g            16g          24g
# ...

# %%
DesayunosRacion.insert(10,'Tipo','Complementos', allow_duplicates=False)
DesayunosRacion
# Out:
#                       Producto Calorias Proteinas Hidratos_Carbono Fibra  \
# 0     Croissant de Mantequilla  204kcal      3,9g              24g  0,3g
# 1  Deseo de Tortilla de Patata  554kcal       13g              60g  4,2g
# 2           Tostada de iberico  345kcal      9,9g              33g  2,6g
# 3  Tostada con Aceite y Tomate  339kcal      6,4g              39g  3,9g
# 4          Muffin de Chocolate  573kcal      7,5g              58g  3,1g
# 5             Redondo Glaseado  206kcal      2,7g              21g  1,7g
# 6               Redondo Bombon  268kcal      3,8g              21g  1,3g
#
#   Azucares Grasas Grasas_Saturadas    Sal Restaurante          Tipo
# 0     3,6g    10g             7,2g  0,55g    Mcdonals  Complementos
# 1     4,4g    28g             5,7g   2,4g    Mcdonals  Complementos
# 2     3,8g    18g             3,6g   1,4g    Mcdonals  Complementos
# 3     2,5g    17g             2,5g  0,93g    Mcdonals  Complementos
# ...

# %%
Ensaladas100.insert(10,'Tipo','Principal', allow_duplicates=False)
EnsaladasRacion.insert(10,'Tipo','Principal', allow_duplicates=False)

# %%
EnsaladasRacion.loc[1,'Hidratos_Carbono'] = '1,1g'
EnsaladasRacion.loc[1,'Fibra'] = '1,4g'
EnsaladasRacion.loc[1,'Azucares'] = '0,8g'
EnsaladasRacion.loc[1,'Grasas'] = '0,2g'
EnsaladasRacion.loc[1,'Grasas_Saturadas'] = '0,1g'
EnsaladasRacion.loc[1,'Sal'] = '0,05g'
EnsaladasRacion.loc[2,'Hidratos_Carbono'] = '3,2g'
EnsaladasRacion.loc[2,'Fibra'] = '2,9g'
EnsaladasRacion.loc[2,'Azucares'] = '2,1g'
EnsaladasRacion.loc[2,'Grasas'] = '16g'
EnsaladasRacion.loc[2,'Grasas_Saturadas'] = '11g'
EnsaladasRacion.loc[2,'Sal'] = '0,65g'
EnsaladasRacion
# Out:
#                   Producto Calorias Proteinas Hidratos_Carbono Fibra Azucares  \
# 0           Ensalada Cesar  351kcal       23g              22g  3,7g     2,1g
# 1    Ensalada de la huerta   12kcal      0,9g             1,1g  1,4g     0,8g
# 2  Ensalada Queso de Cabra  198kcal      9,2g             3,2g  2,9g     2,1g
#
#   Grasas Grasas_Saturadas    Sal Restaurante       Tipo
# 0    18g             6,4g   1,7g    Mcdonals  Principal
# 1   0,2g             0,1g  0,05g    Mcdonals  Principal
# 2    16g              11g  0,65g    Mcdonals  Principal

# %%
Ensaladas100
# Out:
#                   Producto Calorias(100g) Proteinas(100g)  \
# 0           Ensalada Cesar        159kcal             11g
# 1    Ensalada de la huerta         20kcal            1,4g
# 2  Ensalada Queso de Cabra        110kcal            5,1g
#
#   Hidratos_Carbono(100g) Fibra(100g) Azucares(100g) Grasas(100g)  \
# 0                    10g        1,7g             1g         8,2g
# 1                   1,7g        2,2g           1,2g         0,3g
# 2                   1,8g        1,6g           1,1g         8,8g
#
#   Grasas_Saturadas(100g) Sal(100g) Restaurante       Tipo
# 0                   2,9g     0,79g    Mcdonals  Principal
# 1                   0,1g     0,08g    Mcdonals  Principal
# 2                   6,4g     0,36g    Mcdonals  Principal

# %%
Postres100.insert(10,'Tipo','Postre', allow_duplicates=False)
Postres100
# Out:
#                             Producto Calorias(100g) Proteinas(100g)  \
# 0         McFlurry Nocilla y Cookies        220kcal              4g
# 1        Mcflurry M&M con cacahuetes        200kcal            3,6g
# 2                    McFlurry KitKat        199kcal            3,3g
# 3                      McFlurry Oreo        229kcal              4g
# 4     McFlurry Oreo Chocolate Blanco        196kcal            3,7g
# 5                          Apple Pie        294kcal            2,7g
# 6                     Cono de Helado        171kcal            4,1g
# 7                   Sundae Chocolate        169kcal            3,8g
# 8                    Sundae Caramelo        172kcal            3,2g
# 9                       Sundae Fresa        147kcal              3g
# 10           Sundae Chocolate Blanco        199kcal            3,8g
# 11  Mini McFlurry M&Ms con cacahuete        196kcal            4,5g
# 12              Mini McFlurry KitKat        183kcal            3,8g
# ...

# %%
PostresRacion.insert(10,'Tipo','Postre', allow_duplicates=False)

# %%
PostresRacion.loc[1,'Hidratos_Carbono'] = '72g'
PostresRacion.loc[1,'Fibra'] = '0,6g'
PostresRacion.loc[1,'Azucares'] = '55g'
PostresRacion.loc[1,'Grasas'] = '11g'
PostresRacion.loc[1,'Grasas_Saturadas'] = '6,7g'
PostresRacion.loc[1,'Sal'] = '0,36g'
PostresRacion.loc[2,'Hidratos_Carbono'] = '72g'
PostresRacion.loc[2,'Fibra'] = '0,4g'
PostresRacion.loc[2,'Azucares'] = '54g'
PostresRacion.loc[2,'Grasas'] = '11g'
PostresRacion.loc[2,'Grasas_Saturadas'] = '7,2g'
PostresRacion.loc[2,'Sal'] = '0,37g'
PostresRacion.loc[3,'Hidratos_Carbono'] = '62g'
PostresRacion.loc[3,'Fibra'] = '0,4g'
PostresRacion.loc[3,'Azucares'] = '54g'
PostresRacion.loc[3,'Grasas'] = '20g'
PostresRacion.loc[3,'Grasas_Saturadas'] = '8g'
PostresRacion.loc[3,'Sal'] = '0,36g'
PostresRacion
# Out:
#                             Producto Calorias Proteinas Hidratos_Carbono  \
# 0         McFlurry Nocilla y Cookies  434kcal      7,9g              60g
# 1        Mcflurry M&M con cacahuetes  421kcal      7,6g              72g
# 2                    McFlurry KitKat  419kcal        7g              72g
# 3                      McFlurry Oreo  457kcal        8g              62g
# 4     McFlurry Oreo Chocolate Blanco  407kcal      7,7g              65g
# 5                          Apple Pie  250kcal      2,3g              27g
# 6                     Cono de Helado  157kcal      3,8g              28g
# 7                   Sundae Chocolate  281kcal      6,3g              46g
# 8                    Sundae Caramelo  285kcal      5,4g              51g
# 9                       Sundae Fresa  244kcal      4,9g              45g
# 10           Sundae Chocolate Blanco  317kcal        6g              44g
# 11  Mini McFlurry M&Ms con cacahuete  186kcal      4,3g              27g
# ...

# %% [markdown]
# # JUNTAR TABLAS DE 100G

# %%
Postres100,Ensaladas100,Entrantes100,Principales100,Desayunos100
# Out:
# (                            Producto Calorias(100g) Proteinas(100g)  \
#  0         McFlurry Nocilla y Cookies        220kcal              4g
#  1        Mcflurry M&M con cacahuetes        200kcal            3,6g
#  2                    McFlurry KitKat        199kcal            3,3g
#  3                      McFlurry Oreo        229kcal              4g
#  4     McFlurry Oreo Chocolate Blanco        196kcal            3,7g
#  5                          Apple Pie        294kcal            2,7g
#  6                     Cono de Helado        171kcal            4,1g
#  7                   Sundae Chocolate        169kcal            3,8g
#  8                    Sundae Caramelo        172kcal            3,2g
#  9                       Sundae Fresa        147kcal              3g
#  10           Sundae Chocolate Blanco        199kcal            3,8g
#  11  Mini McFlurry M&Ms con cacahuete        196kcal            4,5g
#  12              Mini McFlurry KitKat        183kcal            3,8g
# ...

# %%
uno = Principales100.append(Entrantes100, ignore_index= True)
uno
# Out:
#                                 Producto Calorias(100g) Proteinas(100g)  \
# 0                                 BigMac        232kcal             12g
# 1                         McRoyal_Deluxe        222kcal             12g
# 2                                McSpicy        261kcal             12g
# 3                        Cuarto_de_Libra        255kcal             15g
# 4                                McPollo        229kcal             10g
# 5                                    CBO        255kcal             11g
# 6               Signature_Queso_de_Cabra        278kcal             12g
# 7         Signature_Queso_de_Cabra_Doble        277kcal             15g
# 8         American_Style_Chicken_Buffalo        282kcal             11g
# 9   American_Style_Chicken_Honey_Mustard        291kcal             11g
# 10        Grand_McExtreme_Intense_Chedar        297kcal             17g
# 11  Grand_McExtreme_Intense_Chedar_Doble        290kcal             18g
# ...

# %%
dos = uno.append(Ensaladas100, ignore_index= True)
dos
# Out:
#                                 Producto Calorias(100g) Proteinas(100g)  \
# 0                                 BigMac        232kcal             12g
# 1                         McRoyal_Deluxe        222kcal             12g
# 2                                McSpicy        261kcal             12g
# 3                        Cuarto_de_Libra        255kcal             15g
# 4                                McPollo        229kcal             10g
# 5                                    CBO        255kcal             11g
# 6               Signature_Queso_de_Cabra        278kcal             12g
# 7         Signature_Queso_de_Cabra_Doble        277kcal             15g
# 8         American_Style_Chicken_Buffalo        282kcal             11g
# 9   American_Style_Chicken_Honey_Mustard        291kcal             11g
# 10        Grand_McExtreme_Intense_Chedar        297kcal             17g
# 11  Grand_McExtreme_Intense_Chedar_Doble        290kcal             18g
# ...

# %%
tres = dos.append(Postres100, ignore_index= True)
tres
# Out:
#                                 Producto Calorias(100g) Proteinas(100g)  \
# 0                                 BigMac        232kcal             12g
# 1                         McRoyal_Deluxe        222kcal             12g
# 2                                McSpicy        261kcal             12g
# 3                        Cuarto_de_Libra        255kcal             15g
# 4                                McPollo        229kcal             10g
# 5                                    CBO        255kcal             11g
# 6               Signature_Queso_de_Cabra        278kcal             12g
# 7         Signature_Queso_de_Cabra_Doble        277kcal             15g
# 8         American_Style_Chicken_Buffalo        282kcal             11g
# 9   American_Style_Chicken_Honey_Mustard        291kcal             11g
# 10        Grand_McExtreme_Intense_Chedar        297kcal             17g
# 11  Grand_McExtreme_Intense_Chedar_Doble        290kcal             18g
# ...

# %%
Tabla100gMcdonals = tres.append(Desayunos100, ignore_index= True)
Tabla100gMcdonals
# Out:
#                        Producto Calorias(100g) Proteinas(100g)  \
# 0                        BigMac        232kcal             12g
# 1                McRoyal_Deluxe        222kcal             12g
# 2                       McSpicy        261kcal             12g
# 3               Cuarto_de_Libra        255kcal             15g
# 4                       McPollo        229kcal             10g
# ..                          ...            ...             ...
# 57           Tostada de iberico        270kcal            7,8g
# 58  Tostada con Aceite y Tomate        283kcal            5,3g
# 59          Muffin de Chocolate        441kcal            5,8g
# 60             Redondo Glaseado        412kcal            5,4g
# 61               Redondo Bombon        448kcal            6,9g
#
#    Hidratos_Carbono(100g) Fibra(100g) Azucares(100g) Grasas(100g)  \
# 0                     19g        1,4g           3,9g          12g
# 1                     14g        0,9g           2,9g          13g
# ...

# %% [markdown]
# # JUNTAR TABLAS RACIONES

# %%
PostresRacion,EnsaladasRacion,EntrantesRacion,PrincipalesRacion,DesayunosRacion
# Out:
# (                            Producto Calorias Proteinas Hidratos_Carbono  \
#  0         McFlurry Nocilla y Cookies  434kcal      7,9g              60g
#  1        Mcflurry M&M con cacahuetes  421kcal      7,6g              72g
#  2                    McFlurry KitKat  419kcal        7g              72g
#  3                      McFlurry Oreo  457kcal        8g              62g
#  4     McFlurry Oreo Chocolate Blanco  407kcal      7,7g              65g
#  5                          Apple Pie  250kcal      2,3g              27g
#  6                     Cono de Helado  157kcal      3,8g              28g
#  7                   Sundae Chocolate  281kcal      6,3g              46g
#  8                    Sundae Caramelo  285kcal      5,4g              51g
#  9                       Sundae Fresa  244kcal      4,9g              45g
#  10           Sundae Chocolate Blanco  317kcal        6g              44g
#  11  Mini McFlurry M&Ms con cacahuete  186kcal      4,3g              27g
# ...

# %%
uno = PrincipalesRacion.append(EntrantesRacion, ignore_index= True)
uno
# Out:
#                                 Producto  Calorias Proteinas Hidratos_Carbono  \
# 0                                 BigMac   503kcal       26g              42g
# 1                         McRoyal_Deluxe   530kcal       29g              33g
# 2                                McSpicy   591kcal       27g              51g
# 3                        Cuarto_de_Libra   521kcal       32g              37g
# 4                                McPollo   427kcal       19g              43g
# 5                                    CBO   603kcal       25g              53g
# 6               Signature_Queso_de_Cabra   732kcal       32g              55g
# 7         Signature_Queso_de_Cabra_Doble   962kcal       53g              55g
# 8         American_Style_Chicken_Buffalo   720kcal       28g              79g
# 9   American_Style_Chicken_Honey_Mustard   811kcal       31g              81g
# 10        Grand_McExtreme_Intense_Chedar   736kcal       41g              50g
# ...

# %%
dos = uno.append(EnsaladasRacion, ignore_index= True)
dos
# Out:
#                                 Producto  Calorias Proteinas Hidratos_Carbono  \
# 0                                 BigMac   503kcal       26g              42g
# 1                         McRoyal_Deluxe   530kcal       29g              33g
# 2                                McSpicy   591kcal       27g              51g
# 3                        Cuarto_de_Libra   521kcal       32g              37g
# 4                                McPollo   427kcal       19g              43g
# 5                                    CBO   603kcal       25g              53g
# 6               Signature_Queso_de_Cabra   732kcal       32g              55g
# 7         Signature_Queso_de_Cabra_Doble   962kcal       53g              55g
# 8         American_Style_Chicken_Buffalo   720kcal       28g              79g
# 9   American_Style_Chicken_Honey_Mustard   811kcal       31g              81g
# 10        Grand_McExtreme_Intense_Chedar   736kcal       41g              50g
# ...

# %%
tres = dos.append(PostresRacion, ignore_index= True)
tres
# Out:
#                                 Producto  Calorias Proteinas Hidratos_Carbono  \
# 0                                 BigMac   503kcal       26g              42g
# 1                         McRoyal_Deluxe   530kcal       29g              33g
# 2                                McSpicy   591kcal       27g              51g
# 3                        Cuarto_de_Libra   521kcal       32g              37g
# 4                                McPollo   427kcal       19g              43g
# 5                                    CBO   603kcal       25g              53g
# 6               Signature_Queso_de_Cabra   732kcal       32g              55g
# 7         Signature_Queso_de_Cabra_Doble   962kcal       53g              55g
# 8         American_Style_Chicken_Buffalo   720kcal       28g              79g
# 9   American_Style_Chicken_Honey_Mustard   811kcal       31g              81g
# 10        Grand_McExtreme_Intense_Chedar   736kcal       41g              50g
# ...

# %%
TablaRacionMcdonals =tres.append(DesayunosRacion, ignore_index= True)
TablaRacionMcdonals
# Out:
#                        Producto Calorias Proteinas Hidratos_Carbono Fibra  \
# 0                        BigMac  503kcal       26g              42g  3,1g
# 1                McRoyal_Deluxe  530kcal       29g              33g  2,3g
# 2                       McSpicy  591kcal       27g              51g  3,3g
# 3               Cuarto_de_Libra  521kcal       32g              37g  2,2g
# 4                       McPollo  427kcal       19g              43g  2,5g
# ..                          ...      ...       ...              ...   ...
# 57           Tostada de iberico  345kcal      9,9g              33g  2,6g
# 58  Tostada con Aceite y Tomate  339kcal      6,4g              39g  3,9g
# 59          Muffin de Chocolate  573kcal      7,5g              58g  3,1g
# 60             Redondo Glaseado  206kcal      2,7g              21g  1,7g
# 61               Redondo Bombon  268kcal      3,8g              21g  1,3g
#
#    Azucares Grasas Grasas_Saturadas    Sal Restaurante          Tipo
# ...

# %% [markdown]
# # Arreglar tablas

# %%
DatosMcRacion = TablaRacionMcdonals.drop(['Fibra'], axis=1)

# %%
DatosMcRacion.Calorias = DatosMcRacion.Calorias.str.replace('kcal', '')
DatosMcRacion.Proteinas = DatosMcRacion.Proteinas.str.replace('g', '')
DatosMcRacion.Hidratos_Carbono = DatosMcRacion.Hidratos_Carbono.str.replace('g', '')
DatosMcRacion.Azucares = DatosMcRacion.Azucares.str.replace('g', '')
DatosMcRacion.Azucares = DatosMcRacion.Azucares.str.replace(',', '.')
DatosMcRacion.Grasas_Saturadas = DatosMcRacion.Grasas_Saturadas.str.replace('g', '')
DatosMcRacion.Grasas_Saturadas = DatosMcRacion.Grasas_Saturadas.str.replace(',', '.')
DatosMcRacion.Sal = DatosMcRacion.Sal.str.replace('g', '')
DatosMcRacion.Sal = DatosMcRacion.Sal.str.replace(',', '.')
DatosMcRacion.Grasas = DatosMcRacion.Grasas.str.replace('g', '')
DatosMcRacion.Grasas = DatosMcRacion.Grasas.str.replace(',', '.')
DatosMcRacion.Proteinas = DatosMcRacion.Proteinas.str.replace(',', '.')
DatosMcRacion.Hidratos_Carbono = DatosMcRacion.Hidratos_Carbono.str.replace(',', '.')
DatosMcRacion
# Out:
#                        Producto Calorias Proteinas Hidratos_Carbono Azucares  \
# 0                        BigMac      503        26               42      8.5
# 1                McRoyal_Deluxe      530        29               33      6.9
# 2                       McSpicy      591        27               51        6
# 3               Cuarto_de_Libra      521        32               37      9.5
# 4                       McPollo      427        19               43      5.9
# ..                          ...      ...       ...              ...      ...
# 57           Tostada de iberico      345       9,9               33      3.8
# 58  Tostada con Aceite y Tomate      339       6,4               39      2.5
# 59          Muffin de Chocolate      573       7,5               58       36
# 60             Redondo Glaseado      206       2,7               21        8
# 61               Redondo Bombon      268       3,8               21      6.1
#
# ...

# %%
DatosMcRacion.Calorias = DatosMcRacion.Calorias.astype('float')
DatosMcRacion.Proteinas = DatosMcRacion.Proteinas.astype('float')
DatosMcRacion.Hidratos_Carbono = DatosMcRacion.Hidratos_Carbono.astype('float')
DatosMcRacion.Azucares = DatosMcRacion.Azucares.astype('float')
DatosMcRacion.Grasas = DatosMcRacion.Grasas.astype('float')
DatosMcRacion.Grasas_Saturadas = DatosMcRacion.Grasas_Saturadas.astype('float')
DatosMcRacion.Sal = DatosMcRacion.Sal.astype('float')

# %%
DatosMcRacion
# Out:
#                        Producto  Calorias  Proteinas  Hidratos_Carbono  \
# 0                        BigMac     503.0       26.0              42.0
# 1                McRoyal_Deluxe     530.0       29.0              33.0
# 2                       McSpicy     591.0       27.0              51.0
# 3               Cuarto_de_Libra     521.0       32.0              37.0
# 4                       McPollo     427.0       19.0              43.0
# ..                          ...       ...        ...               ...
# 57           Tostada de iberico     345.0        9.9              33.0
# 58  Tostada con Aceite y Tomate     339.0        6.4              39.0
# 59          Muffin de Chocolate     573.0        7.5              58.0
# 60             Redondo Glaseado     206.0        2.7              21.0
# 61               Redondo Bombon     268.0        3.8              21.0
#
#     Azucares  Grasas  Grasas_Saturadas   Sal Restaurante          Tipo
# ...

# %%
DatosMc100g = Tabla100gMcdonals.drop(['Fibra(100g)'], axis=1)

# %%
DatosMc100g.rename({'Calorias(100g)': 'Calorias_100g'}, axis=1, inplace = True)
DatosMc100g.rename({'Proteinas(100g)': 'Proteinas_100g'}, axis=1, inplace = True)
DatosMc100g.rename({'Hidratos_Carbono(100g)': 'Hidratos_Carbono_100g'}, axis=1, inplace = True)
DatosMc100g.rename({'Azucares(100g)': 'Azucares_100g'}, axis=1, inplace = True)
DatosMc100g.rename({'Grasas(100g)': 'Grasas_100g'}, axis=1, inplace = True)
DatosMc100g.rename({'Grasas_Saturadas(100g)': 'Grasas_Saturadas_100g'}, axis=1, inplace = True)
DatosMc100g.rename({'Sal(100g)': 'Sal_100g'}, axis=1, inplace = True)

# %%
DatosMc100g.Calorias_100g = DatosMc100g.Calorias_100g.str.replace('kcal', '')
DatosMc100g.Proteinas_100g = DatosMc100g.Proteinas_100g.str.replace('g', '')
DatosMc100g.Hidratos_Carbono_100g = DatosMc100g.Hidratos_Carbono_100g.str.replace('g', '')
DatosMc100g.Azucares_100g = DatosMc100g.Azucares_100g.str.replace('g', '')
DatosMc100g.Azucares_100g = DatosMc100g.Azucares_100g.str.replace(',', '.')
DatosMc100g.Grasas_Saturadas_100g = DatosMc100g.Grasas_Saturadas_100g.str.replace('g', '')
DatosMc100g.Grasas_Saturadas_100g = DatosMc100g.Grasas_Saturadas_100g.str.replace(',', '.')
DatosMc100g.Sal_100g = DatosMc100g.Sal_100g.str.replace('g', '')
DatosMc100g.Sal_100g = DatosMc100g.Sal_100g.str.replace(',', '.')
DatosMc100g.Grasas_100g = DatosMc100g.Grasas_100g.str.replace('g', '')
DatosMc100g.Grasas_100g = DatosMc100g.Grasas_100g.str.replace(',', '.')
DatosMc100g.Proteinas_100g = DatosMc100g.Proteinas_100g.str.replace(',', '.')
DatosMc100g.Hidratos_Carbono_100g = DatosMc100g.Hidratos_Carbono_100g.str.replace(',', '.')
DatosMc100g
# Out:
#                        Producto Calorias_100g Proteinas_100g  \
# 0                        BigMac           232             12
# 1                McRoyal_Deluxe           222             12
# 2                       McSpicy           261             12
# 3               Cuarto_de_Libra           255             15
# 4                       McPollo           229             10
# ..                          ...           ...            ...
# 57           Tostada de iberico           270            7.8
# 58  Tostada con Aceite y Tomate           283            5.3
# 59          Muffin de Chocolate           441            5.8
# 60             Redondo Glaseado           412            5.4
# 61               Redondo Bombon           448            6.9
#
#    Hidratos_Carbono_100g Azucares_100g Grasas_100g Grasas_Saturadas_100g  \
# 0                     19           3.9          12                   4.5
# 1                     14           2.9          13                   5.1
# ...

# %%
DatosMc100g.Calorias_100g = DatosMc100g.Calorias_100g.astype('float')
DatosMc100g.Proteinas_100g = DatosMc100g.Proteinas_100g.astype('float')
DatosMc100g.Hidratos_Carbono_100g = DatosMc100g.Hidratos_Carbono_100g.astype('float')
DatosMc100g.Azucares_100g = DatosMc100g.Azucares_100g.astype('float')
DatosMc100g.Grasas_100g = DatosMc100g.Grasas_100g.astype('float')
DatosMc100g.Grasas_Saturadas_100g = DatosMc100g.Grasas_Saturadas_100g.astype('float')
DatosMc100g.Sal_100g = DatosMc100g.Sal_100g.astype('float')

# %%
DatosMc100g
# Out:
#                        Producto  Calorias_100g  Proteinas_100g  \
# 0                        BigMac          232.0            12.0
# 1                McRoyal_Deluxe          222.0            12.0
# 2                       McSpicy          261.0            12.0
# 3               Cuarto_de_Libra          255.0            15.0
# 4                       McPollo          229.0            10.0
# ..                          ...            ...             ...
# 57           Tostada de iberico          270.0             7.8
# 58  Tostada con Aceite y Tomate          283.0             5.3
# 59          Muffin de Chocolate          441.0             5.8
# 60             Redondo Glaseado          412.0             5.4
# 61               Redondo Bombon          448.0             6.9
#
#     Hidratos_Carbono_100g  Azucares_100g  Grasas_100g  Grasas_Saturadas_100g  \
# 0                    19.0            3.9         12.0                    4.5
# ...

# %% [markdown]
# # MOVIMIENTO DE ARCHIVOS

# %%
pwd
# Out:
# 'C:\\Users\\javip\\Lab1\\Proyecto Dashboard'

# %%
pip install openpyxl

# %%
DatosMcRacion.to_excel('TablaRacionMcdonals.xlsx', index = False)
DatosMc100g.to_excel('Tabla100gMcdonals.xlsx', index = False)

# %%
locales2.to_excel('Tabla100gLocales.xlsx', index = False)

# %% [markdown]
# # OTROS ARCHIVOS

# %%
locales = pd.read_excel(r'C:\Users\javip\Documents\Proyecto\100g\Todos100gBuena.xlsx')
locales
# Out:
#                                      Producto  Calorias(100g)  \
# 0        Chick&Share ( 9 tiras de pechuga CR)          240.00
# 1        Chick&Share ( 9 tiras de pechuga OR)          209.00
# 2    Chick&Share ( 9 tiras de pechuga Mixtas)          226.22
# 3           Chick&Share ( 12 Alitas picantes)          319.00
# 4       Chick&Share cruji (6 piezas de pollo)          270.00
# ..                                        ...             ...
# 463                     Ensalada de la huerta           51.00
# 464                            Ensalada césar           96.00
# 465                               Salsa césar          461.00
# 466           Sobre aceite de oliva y vinagre          540.00
# 467                                    Cookie          449.00
#
#      Proteinas(100g)  Hidratos Carbono(100g) Azucares(100g)  Grasas(100g)  \
# 0              19.00                   12.90           0.00          8.40
# ...

# %%
locales = locales.reindex(columns=['Producto','Calorias(100g)','Proteinas(100g)','Hidratos Carbono(100g)','Azucares(100g)','Grasas(100g)','Grasas Saturadas(100g)','Sal(100g)','Dieta(C.N.V.CV)','Restaurante','Tipo'])

# %%
locales
# Out:
#                                      Producto  Calorias(100g)  \
# 0        Chick&Share ( 9 tiras de pechuga CR)          240.00
# 1        Chick&Share ( 9 tiras de pechuga OR)          209.00
# 2    Chick&Share ( 9 tiras de pechuga Mixtas)          226.22
# 3           Chick&Share ( 12 Alitas picantes)          319.00
# 4       Chick&Share cruji (6 piezas de pollo)          270.00
# ..                                        ...             ...
# 463                     Ensalada de la huerta           51.00
# 464                            Ensalada césar           96.00
# 465                               Salsa césar          461.00
# 466           Sobre aceite de oliva y vinagre          540.00
# 467                                    Cookie          449.00
#
#      Proteinas(100g)  Hidratos Carbono(100g) Azucares(100g)  Grasas(100g)  \
# 0              19.00                   12.90           0.00          8.40
# ...

# %%
locales2 = locales.drop(['Dieta(C.N.V.CV)'], axis=1)
locales2
# Out:
#                                      Producto  Calorias(100g)  \
# 0        Chick&Share ( 9 tiras de pechuga CR)          240.00
# 1        Chick&Share ( 9 tiras de pechuga OR)          209.00
# 2    Chick&Share ( 9 tiras de pechuga Mixtas)          226.22
# 3           Chick&Share ( 12 Alitas picantes)          319.00
# 4       Chick&Share cruji (6 piezas de pollo)          270.00
# ..                                        ...             ...
# 463                     Ensalada de la huerta           51.00
# 464                            Ensalada césar           96.00
# 465                               Salsa césar          461.00
# 466           Sobre aceite de oliva y vinagre          540.00
# 467                                    Cookie          449.00
#
#      Proteinas(100g)  Hidratos Carbono(100g) Azucares(100g)  Grasas(100g)  \
# 0              19.00                   12.90           0.00          8.40
# ...

# %%
locales2.rename({'Calorias(100g)': 'Calorias_100g'}, axis=1, inplace = True)
locales2.rename({'Proteinas(100g)': 'Proteinas_100g'}, axis=1, inplace = True)
locales2.rename({'Hidratos Carbono(100g)': 'Hidratos_Carbono_100g'}, axis=1, inplace = True)
locales2.rename({'Azucares(100g)': 'Azucares_100g'}, axis=1, inplace = True)
locales2.rename({'Grasas(100g)': 'Grasas_100g'}, axis=1, inplace = True)
locales2.rename({'Grasas Saturadas(100g)': 'Grasas_Saturadas_100g'}, axis=1, inplace = True)
locales2.rename({'Sal(100g)': 'Sal_100g'}, axis=1, inplace = True)
locales2
# Out:
#                                      Producto  Calorias_100g  Proteinas_100g  \
# 0        Chick&Share ( 9 tiras de pechuga CR)         240.00           19.00
# 1        Chick&Share ( 9 tiras de pechuga OR)         209.00           25.00
# 2    Chick&Share ( 9 tiras de pechuga Mixtas)         226.22           21.67
# 3           Chick&Share ( 12 Alitas picantes)         319.00           15.50
# 4       Chick&Share cruji (6 piezas de pollo)         270.00           21.30
# ..                                        ...            ...             ...
# 463                     Ensalada de la huerta          51.00            3.40
# 464                            Ensalada césar          96.00            8.10
# 465                               Salsa césar         461.00            1.70
# 466           Sobre aceite de oliva y vinagre         540.00            0.00
# 467                                    Cookie         449.00            5.40
#
# ...

# %%
locales2.columns
# Out:
# Index(['Producto', 'Calorias_100g', 'Proteinas_100g', 'Hidratos_Carbono_100g',
#        ')Azucares_100g', 'Grasas_100g', 'Grasas_Saturadas_100g', 'Sal_100g',
#        'Restaurante', 'Tipo'],
#       dtype='object')

# %%
locales2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Producto               468 non-null    object
#  1   Calorias_100g          467 non-null    float64
#  2   Proteinas_100g         467 non-null    float64
#  3   Hidratos_Carbono_100g  467 non-null    float64
#  4   Azucares_100g          467 non-null    object
#  5   Grasas_100g            467 non-null    float64
#  6   Grasas_Saturadas_100g  467 non-null    float64
#  7   Sal_100g               467 non-null    object
#  8   Restaurante            468 non-null    object
#  9   Tipo                   468 non-null    object
# dtypes: float64(5), object(5)
# memory usage: 36.7+ KB

# %%
locales2.Azucares_100g = locales2.Azucares_100g.str.replace(',', '.')



locales2.Sal_100g = locales2.Sal_100g.str.replace(',', '.')

locales2
# Out:
#                                      Producto  Calorias_100g  Proteinas_100g  \
# 0        Chick&Share ( 9 tiras de pechuga CR)         240.00           19.00
# 1        Chick&Share ( 9 tiras de pechuga OR)         209.00           25.00
# 2    Chick&Share ( 9 tiras de pechuga Mixtas)         226.22           21.67
# 3           Chick&Share ( 12 Alitas picantes)         319.00           15.50
# 4       Chick&Share cruji (6 piezas de pollo)         270.00           21.30
# ..                                        ...            ...             ...
# 463                     Ensalada de la huerta          51.00            3.40
# 464                            Ensalada césar          96.00            8.10
# 465                               Salsa césar         461.00            1.70
# 466           Sobre aceite de oliva y vinagre         540.00            0.00
# 467                                    Cookie         449.00            5.40
#
# ...

# %%
locales2.Sal_100g[77] = '0.05'
locales2.Azucares_100g[53] = '0.05'

# %%
locales2.Azucares_100g = locales2.Azucares_100g.astype('float')
locales2.Sal_100g = locales2.Sal_100g.astype('float')

# %%
locales2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Producto               468 non-null    object
#  1   Calorias_100g          467 non-null    float64
#  2   Proteinas_100g         467 non-null    float64
#  3   Hidratos_Carbono_100g  467 non-null    float64
#  4   Azucares_100g          432 non-null    float64
#  5   Grasas_100g            467 non-null    float64
#  6   Grasas_Saturadas_100g  467 non-null    float64
#  7   Sal_100g               455 non-null    float64
#  8   Restaurante            468 non-null    object
#  9   Tipo                   468 non-null    object
# dtypes: float64(7), object(3)
# memory usage: 36.7+ KB

# %%
Restaurantes = locales2.append(DatosMc100g, ignore_index = True)
Restaurantes
# Out:
#                                      Producto  Calorias_100g  Proteinas_100g  \
# 0        Chick&Share ( 9 tiras de pechuga CR)         240.00           19.00
# 1        Chick&Share ( 9 tiras de pechuga OR)         209.00           25.00
# 2    Chick&Share ( 9 tiras de pechuga Mixtas)         226.22           21.67
# 3           Chick&Share ( 12 Alitas picantes)         319.00           15.50
# 4       Chick&Share cruji (6 piezas de pollo)         270.00           21.30
# ..                                        ...            ...             ...
# 525                        Tostada de iberico         270.00            7.80
# 526               Tostada con Aceite y Tomate         283.00            5.30
# 527                       Muffin de Chocolate         441.00            5.80
# 528                          Redondo Glaseado         412.00            5.40
# 529                            Redondo Bombon         448.00            6.90
#
# ...

# %%
Restaurantes.to_excel('Tabla100gRestaurantes.xlsx', index = False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 Goi = pd.read_excel(r'C:\Users\javip\Documents\Proyecto\100g\Goiko100gBuena.xlsx')
#       2 Goi
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # GOIKO y TACOBELL

# %%
Goi = pd.read_excel(r'C:\Users\javip\Documents\Proyecto\100g\Goiko100gBuena.xlsx')
Goi
# Out:
#                 Producto  Calorias_100g  Proteinas_100g  \
# 0            Kevin Bacon     237.771739       12.663043
# 1                    M30     202.034884       14.418605
# 2            Baby Yankee     354.941860       15.232558
# 3                 Yankee     274.906367       16.573034
# 4             Bomba Sexy     286.437613       14.828210
# 5                   Kiki     245.823389       12.725537
# 6                  Pigma     217.422434       13.484487
# 7               Chipotle     170.903010       13.779264
# 8   Carne Extra (unidad)     130.000000       19.000000
# 9               Tequeños     398.000000       10.700000
# 10      Patatas Rusticas     291.772152        1.613924
# 11                Nachos     285.953177        7.809365
# 12    crispy pollo wings     313.235294       11.323529
# 13       Aros de cebolla     528.666667       11.733333
# 14       Chicken Tenders     253.823529       13.441176
# 15            Cesar Bowl     180.615385        9.384615
# ...

# %%
Goi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Producto               23 non-null     object
#  1   Calorias_100g          23 non-null     float64
#  2   Proteina_100g          23 non-null     float64
#  3   Hidratos_Carbono_100g  23 non-null     float64
#  4   Azucares_100g          23 non-null     float64
#  5   Grasas_100g            23 non-null     float64
#  6   Grasas_Saturadas_100g  23 non-null     float64
#  7   Sal_100g               23 non-null     float64
#  8   Restaurante            23 non-null     object
#  9   Tipo                   23 non-null     object
# dtypes: float64(7), object(3)
# memory usage: 1.9+ KB

# %%
Tac = pd.read_excel(r'C:\Users\javip\Documents\Proyecto\100g\TacoBell100gBuena.xlsx')
Tac
# Out:
#                            Producto  Calorias_100g  Proteinas_100g  \
# 0   CRUNCHWRAP SUPREME CARNE PICADA     220.357143        9.857143
# 1    CRUNCHWRAP SUPREME POLLO ASADO     201.785714       11.571429
# 2            CRUNCHWRAP SUPREME VEG     219.642857       10.928571
# 3       CRUNCHWRAP SUPREME FRIJOLES     204.642857        7.000000
# 4            QUESARITO CARNE PICADA     236.129032       10.129032
# ..                              ...            ...             ...
# 85                         AQUARIUS      26.000000        0.000000
# 86                    CERVEZA MAHOU      30.000000        0.200000
# 87                      CERVEZA SIN      25.000000        0.200000
# 88              GRANIZADO MANDARINA      33.250000        0.250000
# 89                 GRANIZADO MOJITO      33.250000        0.250000
#
#     Hidratos_Carbono_100g  Azucares_100g  Grasas_100g  Grasas_Saturadas_100g  \
# 0               21.250000       1.678571    11.607143               4.892857
# ...

# %%
cuarenta = Goi.append(Tac, ignore_index= True)
cuarenta
# Out:
#                 Producto  Calorias_100g  Proteinas_100g  \
# 0            Kevin Bacon     237.771739       12.663043
# 1                    M30     202.034884       14.418605
# 2            Baby Yankee     354.941860       15.232558
# 3                 Yankee     274.906367       16.573034
# 4             Bomba Sexy     286.437613       14.828210
# ..                   ...            ...             ...
# 108             AQUARIUS      26.000000        0.000000
# 109        CERVEZA MAHOU      30.000000        0.200000
# 110          CERVEZA SIN      25.000000        0.200000
# 111  GRANIZADO MANDARINA      33.250000        0.250000
# 112     GRANIZADO MOJITO      33.250000        0.250000
#
#      Hidratos_Carbono_100g  Azucares_100g  Grasas_100g  Grasas_Saturadas_100g  \
# 0                14.021739       1.956522    12.309783               5.298913
# 1                13.691860       1.831395     8.546512               4.476744
# ...

# %%
cuarenta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Producto               113 non-null    object
#  1   Calorias_100g          113 non-null    float64
#  2   Proteinas_100g         113 non-null    float64
#  3   Hidratos_Carbono_100g  113 non-null    float64
#  4   Azucares_100g          113 non-null    float64
#  5   Grasas_100g            113 non-null    float64
#  6   Grasas_Saturadas_100g  113 non-null    float64
#  7   Sal_100g               113 non-null    float64
#  8   Restaurante            113 non-null    object
#  9   Tipo                   113 non-null    object
# dtypes: float64(7), object(3)
# memory usage: 9.0+ KB

# %%
todos = pd.read_excel(r'C:\Users\javip\Documents\Proyecto\100g\Tabla100gRestaurantes.xlsx')
todos
# Out:
#                                               Producto  Calorias_100g  \
# 0                 Chick&Share ( 9 tiras de pechuga CR)         240.00
# 1                 Chick&Share ( 9 tiras de pechuga OR)         209.00
# 2             Chick&Share ( 9 tiras de pechuga Mixtas)         226.22
# 3                    Chick&Share ( 12 Alitas picantes)         319.00
# 4                Chick&Share cruji (6 piezas de pollo)         270.00
# 5             Chick&Share original (6 piezas de pollo)         241.00
# 6               Chick&Share mixto (3cruji+ 3 original)         255.50
# 7    Menú para 2( 5 piezas de pollo OR + 5 alitas p...         258.47
# 8    Menú para 2( 5 piezas de pollo cruji + 5 alita...         279.73
# 9                  Menú para 2(12 tiras de pechuga CR)         240.00
# 10                 Menú para 2(12 tiras de pechuga OR)         209.00
# 11             Menú para 2(12 tiras de pechuga mixtas)         224.50
# ...

# %%
todos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Producto               529 non-null    object
#  1   Calorias_100g          529 non-null    float64
#  2   Proteinas_100g         529 non-null    float64
#  3   Hidratos_Carbono_100g  529 non-null    float64
#  4   Azucares_100g          529 non-null    float64
#  5   Grasas_100g            529 non-null    float64
#  6   Grasas_Saturadas_100g  529 non-null    float64
#  7   Sal_100g               529 non-null    float64
#  8   Restaurante            529 non-null    object
#  9   Tipo                   529 non-null    object
# dtypes: float64(7), object(3)
# memory usage: 41.5+ KB

# %%
TodosFin = todos.append(cuarenta, ignore_index = True)
TodosFin
# Out:
#                                               Producto  Calorias_100g  \
# 0                 Chick&Share ( 9 tiras de pechuga CR)     240.000000
# 1                 Chick&Share ( 9 tiras de pechuga OR)     209.000000
# 2             Chick&Share ( 9 tiras de pechuga Mixtas)     226.220000
# 3                    Chick&Share ( 12 Alitas picantes)     319.000000
# 4                Chick&Share cruji (6 piezas de pollo)     270.000000
# 5             Chick&Share original (6 piezas de pollo)     241.000000
# 6               Chick&Share mixto (3cruji+ 3 original)     255.500000
# 7    Menú para 2( 5 piezas de pollo OR + 5 alitas p...     258.470000
# 8    Menú para 2( 5 piezas de pollo cruji + 5 alita...     279.730000
# 9                  Menú para 2(12 tiras de pechuga CR)     240.000000
# 10                 Menú para 2(12 tiras de pechuga OR)     209.000000
# 11             Menú para 2(12 tiras de pechuga mixtas)     224.500000
# ...

# %%
TodosFin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642 entries, 0 to 641
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Producto               642 non-null    object
#  1   Calorias_100g          642 non-null    float64
#  2   Proteinas_100g         642 non-null    float64
#  3   Hidratos_Carbono_100g  642 non-null    float64
#  4   Azucares_100g          642 non-null    float64
#  5   Grasas_100g            642 non-null    float64
#  6   Grasas_Saturadas_100g  642 non-null    float64
#  7   Sal_100g               642 non-null    float64
#  8   Restaurante            642 non-null    object
#  9   Tipo                   642 non-null    object
# dtypes: float64(7), object(3)
# memory usage: 50.3+ KB

# %%
TodosFin.to_excel('Todos100gFIN.xlsx', index = False)
